# %% [markdown]
# ### 変数定義

# %%
catalog = "my_lab"
schema = "mydocs_rag"

bronze_table_path = "my_lab.mydocs_rag.mydocs_chunk_bronze"
vector_index = "mydocs_chunk_index"
vector_index_path = f"{catalog}.{schema}.{vector_index}"
model_name = "mydocs_assistant_1"
model_path = f"{catalog}.{schema}.{model_name}"

src_directory_path = "/Workspace/Users/a2c6201@gmail.com/databricks-rag/src"

print(f"catalog = {catalog}")
print(f"schema = {schema}")
print(f"bronze_table_path = {bronze_table_path}")
print(f"vector_index_path = {vector_index_path}")
print(f"src_directory = {src_directory_path}")
