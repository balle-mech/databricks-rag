# %%
import mlflow

with mlflow.start_run():
    mlflow.pyfunc.log_model(
        artifact_path="mydocs_chatbot",
        python_model=MyRAGAgent(vector_index, llm),
        registered_model_name=model_path
    )
